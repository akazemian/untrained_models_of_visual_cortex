# %%
import os
import sys
import pickle

import pandas as pd
import numpy as np
from matplotlib.pyplot import rcParams
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
CURRENT_DIR = os.getcwd()

# Set the root directory to the parent of the current directory
ROOT = os.path.abspath(os.path.join(CURRENT_DIR, os.pardir))
sys.path.insert(0, ROOT)

from notebooks.plotting_tools import *
from code_.model_configs import model_cfg

# %%
RESULTS_PATH = os.path.join(ROOT,'results_fully_connected_old_no_nl')

# %%
models_features_config = {
    # 'vit': {'multiplier': 196},
    'expansion': {'multiplier': 36},
    'expansion_normal': {'multiplier': 36},
    'fully_connected': {'multiplier': 36}
}

def load_and_prepare_data(model_name, multiplier, dataset, region):
    filepath = os.path.join(RESULTS_PATH, model_name + '_' + dataset + '_' + region + '.pkl')
    with open(filepath, 'rb') as file:
        df = pickle.load(file)
    df['model'] = model_name
    df['features'] = df['features'].apply(lambda x: int(x) * multiplier)
    df['score'] = df['score'].astype(np.float32)
    return df

# %% [markdown]
# # Main results

# %%
DATASET = 'naturalscenes' # one of ['majajhong', 'naturalscenes']
region = 'early visual stream' # for majajhong: [V4,IT], for naturalscenes: [early visual stream, midventral visual stream, ventral visual stream]

# %%
DATASET = 'majajhong'#, 'naturalscenes']
region = 'IT' #[V4,IT], for naturalscenes: [early visual stream, midventral visual stream, ventral visual stream]

# %%
# Process each model
all_dfs = []
for model_name, config in models_features_config.items():
    if model_name == 'expansion_normal':
        features_list = model_cfg[DATASET]['models']['expansion']['features']
    else:
        features_list = model_cfg[DATASET]['models'][model_name]['features']
    df_model = load_and_prepare_data(model_name, config['multiplier'], DATASET, region)
    all_dfs.append(df_model)

# Combine all dataframes and reset index
df = pd.concat(all_dfs).reset_index(drop=True)

# %%
# alexnet data
with open(os.path.join(RESULTS_PATH, 'alexnet' + '_' + DATASET + '_' + region + '.pkl'), 'rb') as file:
    df_alexnet = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # alexnet data
# ----> 2 with open(os.path.join(RESULTS_PATH, 'alexnet' + '_' + DATASET + '_' + region + '.pkl'), 'rb') as file:
#       3     df_alexnet = pickle.load(file)
#
# File /data/shared/miniconda3/envs/repo_test/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/akazemi3/Desktop/untrained_models_of_visual_cortex/results_fully_connected_old_no_nl/alexnet_majajhong_IT.pkl'

# %%
df
# Out:
#                model  features   pcs        init_type nl_type     score  \
# 0          expansion       108  None  kaiming_uniform    relu  0.324912
# 1          expansion      1080  None  kaiming_uniform    relu  0.462385
# 2          expansion     10800  None  kaiming_uniform    relu  0.532320
# 3          expansion    108000  None  kaiming_uniform    relu  0.551966
# 4          expansion   1080000  None  kaiming_uniform    relu  0.557964
# 5   expansion_normal       108  None  kaiming_uniform    relu  0.222186
# 6   expansion_normal      1080  None  kaiming_uniform    relu  0.437755
# 7   expansion_normal     10800  None  kaiming_uniform    relu  0.516035
# 8   expansion_normal    108000  None  kaiming_uniform    relu  0.554685
# 9   expansion_normal   1080000  None  kaiming_uniform    relu  0.563468
# 10   fully_connected       108  None  kaiming_uniform    relu  0.161208
# 11   fully_connected      1080  None  kaiming_uniform    relu  0.223291
# 12   fully_connected     10800  None  kaiming_uniform    relu  0.236610
# 13   fully_connected    108000  None  kaiming_uniform    relu  0.246153
# 14   fully_connected   1080000  None  kaiming_uniform    relu  0.233421
#
#        lower     upper
# 0   0.306885  0.341388
# 1   0.446390  0.476923
# 2   0.518589  0.544776
# 3   0.538126  0.564487
# 4   0.544921  0.570704
# 5   0.203469  0.239874
# 6   0.424032  0.453590
# 7   0.503226  0.529746
# 8   0.542729  0.567354
# 9   0.551565  0.575673
# 10  0.147229  0.176259
# 11  0.206729  0.238640
# 12  0.220799  0.252538
# 13  0.230722  0.261851
# 14  0.216813  0.250050

# %%
names ={'expansion':'Convolutional',
        'expansion_normal': 'Convolutional_normal',
        'vit':'Transformer',
        'fully_connected':'Fully connected'}
palette ={'Convolutional':'royalblue',
          'Transformer':'palevioletred',
          'Fully connected':'darkviolet',
         'Convolutional_normal':'red'}

df['model'] = df['model'].map(names)
df['color'] = df['model'].map(palette)

# %%
df
# Out:
#                    model  features   pcs        init_type nl_type     score  \
# 0          Convolutional       108  None  kaiming_uniform    relu  0.324912
# 1          Convolutional      1080  None  kaiming_uniform    relu  0.462385
# 2          Convolutional     10800  None  kaiming_uniform    relu  0.532320
# 3          Convolutional    108000  None  kaiming_uniform    relu  0.551966
# 4          Convolutional   1080000  None  kaiming_uniform    relu  0.557964
# 5   Convolutional_normal       108  None  kaiming_uniform    relu  0.222186
# 6   Convolutional_normal      1080  None  kaiming_uniform    relu  0.437755
# 7   Convolutional_normal     10800  None  kaiming_uniform    relu  0.516035
# 8   Convolutional_normal    108000  None  kaiming_uniform    relu  0.554685
# 9   Convolutional_normal   1080000  None  kaiming_uniform    relu  0.563468
# 10       Fully connected       108  None  kaiming_uniform    relu  0.161208
# 11       Fully connected      1080  None  kaiming_uniform    relu  0.223291
# 12       Fully connected     10800  None  kaiming_uniform    relu  0.236610
# 13       Fully connected    108000  None  kaiming_uniform    relu  0.246153
# 14       Fully connected   1080000  None  kaiming_uniform    relu  0.233421
#
#        lower     upper       color
# 0   0.306885  0.341388   royalblue
# 1   0.446390  0.476923   royalblue
# 2   0.518589  0.544776   royalblue
# 3   0.538126  0.564487   royalblue
# 4   0.544921  0.570704   royalblue
# 5   0.203469  0.239874         red
# 6   0.424032  0.453590         red
# 7   0.503226  0.529746         red
# 8   0.542729  0.567354         red
# 9   0.551565  0.575673         red
# 10  0.147229  0.176259  darkviolet
# 11  0.206729  0.238640  darkviolet
# 12  0.220799  0.252538  darkviolet
# 13  0.230722  0.261851  darkviolet
# 14  0.216813  0.250050  darkviolet

# %%
rcParams['figure.figsize'] = (6,6)  

# main plot
ax1 = sns.lineplot(data = df, x='features', y='score', hue='model', marker='o', palette = palette)
# adding error bars for the 95% confidence interval
for i in range(len(df)):
    plt.errorbar(df['features'][i], df['score'][i], 
                 yerr=[[df['score'][i] - df['lower'][i]], [df['upper'][i] - df['score'][i]]], 
                 fmt='none', capsize=5, color=df['color'][i])   
    
# # alexnet 
# plt.axhline(y=df_alexnet['score'][0], color='gray', linestyle='--', label='AlexNet')

# # adding 95% confidence interval 
# plt.fill_between(np.arange(df['features'].min()/3,df['features'].max()*3), 
#                  df_alexnet['lower'], df_alexnet['upper'], color='gray', alpha=0.2)

plt.ylim(0,0.45) if DATASET == 'naturalscenes' else plt.ylim(0,0.65)
plt.xlabel('')
plt.ylabel('')
plt.xlim(df['features'].min()/3,df['features'].max()*3)
plt.xticks(size=15)
plt.yticks(size=15)
ax1.set_xscale("log")        
ax1.legend(frameon=False,fontsize=12) if region == 'V4' else ax1.legend_.remove()
plt.savefig(os.path.join(ROOT, f'figures/figure_2_{DATASET}_{region}.png'), dpi=200) 
plt.show()

# %%
rcParams['figure.figsize'] = (6,6)  

# main plot
ax1 = sns.lineplot(data = df, x='features', y='score', hue='model', marker='o', palette = palette)
# adding error bars for the 95% confidence interval
for i in range(len(df)):
    plt.errorbar(df['features'][i], df['score'][i], 
                 yerr=[[df['score'][i] - df['lower'][i]], [df['upper'][i] - df['score'][i]]], 
                 fmt='none', capsize=5, color=df['color'][i])   
    
# # alexnet 
# plt.axhline(y=df_alexnet['score'][0], color='gray', linestyle='--', label='AlexNet')

# # adding 95% confidence interval 
# plt.fill_between(np.arange(df['features'].min()/3,df['features'].max()*3), 
#                  df_alexnet['lower'], df_alexnet['upper'], color='gray', alpha=0.2)

plt.ylim(0,0.45) if DATASET == 'naturalscenes' else plt.ylim(0,0.65)
plt.xlabel('')
plt.ylabel('')
plt.xlim(df['features'].min()/3,df['features'].max()*3)
plt.xticks(size=15)
plt.yticks(size=15)
ax1.set_xscale("log")        
ax1.legend(frameon=False,fontsize=12) if region == 'V4' else ax1.legend_.remove()
plt.savefig(os.path.join(ROOT, f'figures/figure_2_{DATASET}_{region}.png'), dpi=200) 
plt.show()

# %%
rcParams['figure.figsize'] = (6,6)  

# main plot
ax1 = sns.lineplot(data = df, x='features', y='score', hue='model', marker='o', palette = palette)
# adding error bars for the 95% confidence interval
for i in range(len(df)):
    plt.errorbar(df['features'][i], df['score'][i], 
                 yerr=[[df['score'][i] - df['lower'][i]], [df['upper'][i] - df['score'][i]]], 
                 fmt='none', capsize=5, color=df['color'][i])   
    
# # alexnet 
# plt.axhline(y=df_alexnet['score'][0], color='gray', linestyle='--', label='AlexNet')

# # adding 95% confidence interval 
# plt.fill_between(np.arange(df['features'].min()/3,df['features'].max()*3), 
#                  df_alexnet['lower'], df_alexnet['upper'], color='gray', alpha=0.2)

plt.ylim(0,0.45) if DATASET == 'naturalscenes' else plt.ylim(0,0.65)
plt.xlabel('')
plt.ylabel('')
plt.xlim(df['features'].min()/3,df['features'].max()*3)
plt.xticks(size=15)
plt.yticks(size=15)
ax1.set_xscale("log")        
ax1.legend(frameon=False,fontsize=12) if region == 'V4' else ax1.legend_.remove()
plt.savefig(os.path.join(ROOT, f'figures/figure_2_{DATASET}_{region}.png'), dpi=200) 
plt.show()

# %%
df
# Out:
#               model  features   pcs        init_type nl_type     score  \
# 0       Transformer      2352  None  kaiming_uniform    relu  0.280039
# 1       Transformer     11760  None  kaiming_uniform    relu  0.339030
# 2       Transformer    117600  None  kaiming_uniform    relu  0.351363
# 3       Transformer   1176000  None  kaiming_uniform    relu  0.354708
# 4     Convolutional       108  None  kaiming_uniform    relu  0.235578
# 5     Convolutional      1080  None  kaiming_uniform    relu  0.437788
# 6     Convolutional     10800  None  kaiming_uniform    relu  0.515993
# 7     Convolutional    108000  None  kaiming_uniform    relu  0.554680
# 8     Convolutional   1080000  None  kaiming_uniform    relu  0.563389
# 9   Fully connected       108  None  kaiming_uniform    relu  0.177279
# 10  Fully connected      1080  None  kaiming_uniform    relu  0.224180
# 11  Fully connected     10800  None  kaiming_uniform    relu  0.240039
# 12  Fully connected    108000  None  kaiming_uniform    relu  0.226817
# 13  Fully connected   1080000  None  kaiming_uniform    relu  0.237656
#
#        lower     upper          color
# 0   0.263639  0.296941  palevioletred
# 1   0.322841  0.355048  palevioletred
# 2   0.335033  0.366711  palevioletred
# 3   0.337441  0.370558  palevioletred
# 4   0.218704  0.252945      royalblue
# 5   0.422916  0.452817      royalblue
# 6   0.503318  0.528563      royalblue
# 7   0.541896  0.567553      royalblue
# 8   0.551498  0.575841      royalblue
# 9   0.161166  0.193902     darkviolet
# 10  0.207201  0.239943     darkviolet
# 11  0.225015  0.255445     darkviolet
# 12  0.210360  0.244172     darkviolet
# 13  0.221011  0.255278     darkviolet

# %%
rcParams['figure.figsize'] = (6,6)  

# main plot
ax1 = sns.lineplot(data = df, x='features', y='score', hue='model', marker='o', palette = palette)
# adding error bars for the 95% confidence interval
for i in range(len(df)):
    plt.errorbar(df['features'][i], df['score'][i], 
                 yerr=[[df['score'][i] - df['lower'][i]], [df['upper'][i] - df['score'][i]]], 
                 fmt='none', capsize=5, color=df['color'][i])   
    
# alexnet 
# plt.axhline(y=df_alexnet['score'][0], color='gray', linestyle='--', label='AlexNet')

# adding 95% confidence interval 
# plt.fill_between(np.arange(df['features'].min()/3,df['features'].max()*3), 
#                  df_alexnet['lower'], df_alexnet['upper'], color='gray', alpha=0.2)

plt.ylim(0,0.45) if DATASET == 'naturalscenes' else plt.ylim(0,0.65)
plt.xlabel('')
plt.ylabel('')
plt.xlim(df['features'].min()/3,df['features'].max()*3)
plt.xticks(size=15)
plt.yticks(size=15)
ax1.set_xscale("log")        
ax1.legend(frameon=False,fontsize=12) if region == 'V4' else ax1.legend_.remove()
plt.savefig(os.path.join(ROOT, f'figures/figure_2_{DATASET}_{region}.png'), dpi=200) 
plt.show()

# %%
df
# Out:
#            model  features   pcs        init_type nl_type     score     lower  \
# 0  Convolutional       108  None  kaiming_uniform    relu  0.258651  0.239271
# 1  Convolutional      1080  None  kaiming_uniform    relu  0.503794  0.489213
# 2  Convolutional     10800  None  kaiming_uniform    relu  0.561076  0.548545
# 3  Convolutional    108000  None  kaiming_uniform    relu  0.587812  0.575827
# 4  Convolutional   1080000  None  kaiming_uniform    relu  0.591564  0.579224
#
#       upper      color
# 0  0.277657  royalblue
# 1  0.519774  royalblue
# 2  0.573552  royalblue
# 3  0.599370  royalblue
# 4  0.602641  royalblue

# %%
rcParams['figure.figsize'] = (6,6)  

# main plot
ax1 = sns.lineplot(data = df, x='features', y='score', hue='model', marker='o', palette = palette)
# adding error bars for the 95% confidence interval
for i in range(len(df)):
    plt.errorbar(df['features'][i], df['score'][i], 
                 yerr=[[df['score'][i] - df['lower'][i]], [df['upper'][i] - df['score'][i]]], 
                 fmt='none', capsize=5, color=df['color'][i])   
    
# alexnet 
# plt.axhline(y=df_alexnet['score'][0], color='gray', linestyle='--', label='AlexNet')

# adding 95% confidence interval 
# plt.fill_between(np.arange(df['features'].min()/3,df['features'].max()*3), 
#                  df_alexnet['lower'], df_alexnet['upper'], color='gray', alpha=0.2)

plt.ylim(0,0.45) if DATASET == 'naturalscenes' else plt.ylim(0,0.65)
plt.xlabel('')
plt.ylabel('')
plt.xlim(df['features'].min()/3,df['features'].max()*3)
plt.xticks(size=15)
plt.yticks(size=15)
ax1.set_xscale("log")        
ax1.legend(frameon=False,fontsize=12) if region == 'V4' else ax1.legend_.remove()
plt.savefig(os.path.join(ROOT, f'figures/figure_2_{DATASET}_{region}.png'), dpi=200) 
plt.show()

# %%
df
# Out:
#            model  features   pcs        init_type nl_type     score     lower  \
# 0  Convolutional       108  None  kaiming_uniform    relu  0.293090  0.275214
# 1  Convolutional      1080  None  kaiming_uniform    relu  0.447063  0.432401
# 2  Convolutional     10800  None  kaiming_uniform    relu  0.512441  0.498939
# 3  Convolutional    108000  None  kaiming_uniform    relu  0.557585  0.544545
#
#       upper      color
# 0  0.311319  royalblue
# 1  0.462260  royalblue
# 2  0.527370  royalblue
# 3  0.570619  royalblue

# %% [markdown]
# # Scaling effect

# %%
DATASET = 'naturalscenes'
regions = model_cfg[DATASET]['regions']

# %%
# Configurations for models and features
models_config = {
    'expansion': {'min_features': 108, 'max_features': 1080000},
    'fully_connected': {'min_features': 108, 'max_features': 1080000},
    'vit': {'min_features': 2352, 'max_features': 1176000}
}

# Dataset dependent changes
if DATASET == 'naturalscenes':
    models_config['expansion']['max_features']/=10 
    models_config['fully_connected']['max_features']/=10 
    models_config['vit']['max_features']/=10 

# Data initialization
ratios_dicts = {model: {'region':[], 'dataset':[], 'model':[], 'smallest model score':[], 'largest model score':[], 'difference':[]} for model in models_config}


# Loop through regions and models
for region in regions:
    for model_name, config in models_config.items():
        df_model = load_and_prepare_data(model_name, models_features_config[model_name]['multiplier'], DATASET, region)
        smallest_score = float(df_model[df_model.features == config['min_features']]['score'].item())
        largest_score = float(df_model[df_model.features == config['max_features']]['score'].item())
        
        ratios_dicts[model_name]['region'].append(region)
        ratios_dicts[model_name]['dataset'].append(DATASET)
        ratios_dicts[model_name]['model'].append(model_name)
        ratios_dicts[model_name]['smallest model score'].append(smallest_score)
        ratios_dicts[model_name]['largest model score'].append(largest_score)
        ratios_dicts[model_name]['difference'].append(largest_score - smallest_score)

# Concatenate all dataframes
df = pd.concat([pd.DataFrame.from_dict(ratios_dicts[model]) for model in models_config]).reset_index(drop=True)

# plot
df['model'] = df['model'].map({'expansion': 'Convolution', 'vit': 'Transformer', 'fully_connected': 'Fully connected'})
palette = {'Convolution': 'royalblue', 'Transformer': 'palevioletred', 'Fully connected': 'darkviolet'}

plt.figure(figsize=(10,10))
ax1 = sns.barplot(x='region', y='difference', hue='model', width=0.6, palette=palette, data=df)
plt.xlabel('')
plt.ylabel('')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylim(0, 0.3 if DATASET == 'naturalscenes' else 0.45)
ax1.legend(frameon=False, fontsize=12)
for spine in ax1.spines.values():
    spine.set_linewidth(1)
ax1.xaxis.set_tick_params(width=1)
ax1.yaxis.set_tick_params(width=1)
plt.savefig(os.path.join(ROOT,f'figures/figure_2_scaling_effect_{DATASET}_{region}.png'), dpi=200)
