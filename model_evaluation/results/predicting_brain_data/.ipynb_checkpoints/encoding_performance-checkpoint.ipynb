# %%
import os
import sys
ROOT = os.getenv('BONNER_ROOT_PATH')
sys.path.append(ROOT)
from model_evaluation.results.predicting_brain_data.tools import plot_results, get_scores_iden
from model_features.models.models import load_model_dict
from config import CACHE

# %% [markdown]
# # Main Results

# %% [markdown]
# ### expansion model

# %%
dataset = 'naturalscenes'
hook = None
gpool = False

data_dict = {}
models = ['expansion_10','expansion_100','expansion_1000','expansion_10000']
for model in models:
    data_dict[model] = load_model_dict(model,gpool=gpool)
    
palette = {'expansion_model':'mediumseagreen'}

# %% [markdown]
# #### V1

# %%
regions = ['V1']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# #### V2

# %%
regions = ['V2']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# #### V3

# %%
regions = ['V3']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# #### V4

# %%
regions = ['V4']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# #### nsd general

# %%
regions = ['general']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.35), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool=False')

# %% [markdown]
# ### alexnet

# %%
dataset = 'naturalscenes'
hook = None
mode = 'ridgecv'
gpool = False

# %% [markdown]
# #### V1

# %%
regions = ['V1']

data_dict = {}
models = [get_scores_iden(['alexnet','best_layer', regions[0], dataset,'gpool=False'], ['untrained'])]
#,get_scores_iden(['alexnet_untrained','best_layer', regions[0], dataset,'gpool=False'])]

for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name,gpool=gpool)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue'}#, layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True, data_dict = data_dict, plot_type = 'compare_models', 
             dataset = dataset, regions = regions,
             palette=palette,
             ylim = (0,0.45), 
             width = 0.55, 
             show_legend= False, 
             params = (3.5,7), 
             file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# #### V2

# %%
regions = ['V2']

data_dict = {}
models = [get_scores_iden(['alexnet','best_layer', regions[0], dataset,'gpool=False'], ['untrained'])]
#,get_scores_iden(['alexnet_untrained','best_layer', regions[0], dataset,'gpool=False'])]

for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name,gpool=gpool)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue'}#, layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True, data_dict = data_dict, plot_type = 'compare_models', 
             dataset = dataset, regions = regions,
             palette=palette,
             ylim = (0,0.45), 
             width = 0.55, 
             show_legend= False, 
             params = (3.5,7), 
             file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# #### V3

# %%
regions = ['V3']

data_dict = {}
models = [get_scores_iden(['alexnet','best_layer', regions[0], dataset,'gpool=False'], ['untrained'])]
#          ,get_scores_iden(['alexnet_untrained','best_layer', regions[0], dataset,'gpool=False'])]

for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name,gpool=gpool)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue'}#, layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True,data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (3.5,7), 
                 file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# #### V4

# %%
regions = ['V4']

data_dict = {}
models = [get_scores_iden(['alexnet','best_layer', regions[0], dataset,'gpool=False'], ['untrained'])]
#, get_scores_iden(['alexnet_untrained','best_layer', regions[0], dataset,'gpool=False'])]

for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name,gpool=gpool)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue'}#, layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True,data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.45), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (3.5,7), 
                 file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# #### nsd general

# %%
regions = ['general']

data_dict = {}
models = [get_scores_iden(['alexnet','best_layer', regions[0], dataset,'gpool=False'], ['untrained'])]
          #get_scores_iden(['alexnet_untrained','best_layer', regions[0], dataset,'gpool=False'])]

for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name,gpool=gpool)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue'}#, layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True,data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.35), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (3.5,7), 
                 file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# # Additional Results: Majajhong Data

# %% [markdown]
# ### expansion

# %%
dataset = 'majajhong'
mode = 'ridgecv'
hook = None
gpool = False

data_dict = {}
models = ['expansion_10','expansion_100','expansion_1000','expansion_10000']
for model in models:
    data_dict[model] = load_model_dict(model,gpool=gpool)
    
palette = {'expansion_model':'mediumseagreen'}

# %% [markdown]
# #### V4

# %%
regions = ['V4']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.65), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# #### IT

# %%
regions = ['IT']

plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis = 'num_features',
                 dataset = dataset, regions = regions,  
                 palette=palette,
                 ylim = (0,0.65), 
                 width = 0.55, 
                 show_legend= False, 
                 params = (7,8), 
                 name_dict= None, 
                 file_name=f'expansion_{dataset}_{regions}_gpool={gpool}')

# %% [markdown]
# ### alexnet

# %% [markdown]
# #### V4

# %%
dataset = 'majajhong'
hook = None
mode = 'ridgecv'
gpool = True
model_family = 'alexnet'

# %%
regions = ['V4']

data_dict = {}
models = load_best_layer_scores(model=model_family, dataset=dataset, region=regions[0])
for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue', layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True,data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.65), 
                 width = 0.58, 
                 show_legend= False, 
                 params = (3,8), 
                 file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# #### IT

# %%
regions = ['IT']

data_dict = {}
models = load_best_layer_scores(model=model_family, dataset=dataset, region=regions[0])
for iden in models:
    iden = iden.split('_')
    model_name = iden[0] + '_' + iden[1] +  '_' + iden[2] if 'untrained' in iden else iden[0] + '_' + iden[1] 
    data_dict[model_name] = load_model_dict(model_name)
        
    
layer_names = list(data_dict.keys())
palette = {layer_names[0]:'steelblue', layer_names[1]:'darkgray'}

# %%
plot_results(best_layer=True,data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.65), 
                 width = 0.58, 
                 show_legend= False, 
                 params = (3,8), 
                 file_name=f'{dataset}_{regions}_alexnet')

# %% [markdown]
# # Effect of wavelet filters

# %%
dataset = 'naturalscenes'
regions = ['general']
mode = 'ridgecv'

data_dict = {}
models = ['expansion_10000', 'fully_random']
for model in models:
    data_dict[model] = load_model_dict(model)
    
name_dict = {'expansion_model':'Wavelet','expansion_model_fully_random':'Random'}
palette = {'Wavelet':'mediumseagreen','Random':'orange'}

# %%
plot_results(data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.35), 
                 width = 0.6, 
                 show_legend= False, 
                 params = (5,10), 
                 name_dict= name_dict, 
                 file_name=f'effect_of_wavelet_filters')

# %% [markdown]
# # Effect of Architecture

# %%
dataset = 'naturalscenes'
regions = ['general']
mode = 'ridgecv'

data_dict = {}
models = ['fully_connected_10', 'fully_connected_100', 'fully_connected_1000', 'fully_connected_10000', 
          'fully_connected_3_layers_10', 'fully_connected_3_layers_100', 'fully_connected_3_layers_1000', 'fully_connected_3_layers_10000',
          'expansion_10', 'expansion_100', 'expansion_1000', 'expansion_10000']
for model in models:
    data_dict[model] = load_model_dict(model)
    
name_dict = {'fully_connected':'Fully Connected', 'fully_connected_3_layers':'Fully Connected 3 Layers','expansion_model':'Expansion Model'}
palette = {'Expansion Model':'mediumseagreen','Fully Connected':'plum', 'Fully Connected 3 Layers':'mediumslateblue'}

# %%
plot_results(data_dict = data_dict, plot_type = 'scores_vs_num_features', x_axis='num_features',
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.37), 
                 width = 0.8, 
                 show_legend= True, 
                 params = (12, 12), 
                 name_dict= name_dict, 
                 file_name=f'effect_of_architecture')

# %% [markdown]
# # Effect of high dim regression

# %%
dataset = 'naturalscenes'
regions = ['general']
mode = 'ridgecv'

# %% [markdown]
# #### expansion vs linear model

# %%
data_dict = {}
models = ['expansion_10000', 'expansion_linear']
for model in models:
    data_dict[model] = load_model_dict(model)
    
name_dict = {'expansion_model':'Expansion Model','expansion_model_linear':'Linear Model'}
palette = {'Expansion Model':'mediumseagreen','Linear Model':'rosybrown'}

# %%
plot_results(data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions, 
                 palette=palette,
                 ylim = (0,0.37), 
                 width = 0.5, 
                 show_legend= True, 
                 params = (5.5,10), 
                 name_dict= name_dict, 
                 file_name=f'expansion_vs_linear')

# %% [markdown]
# #### expansion model PCs vs alexnet

# %%
data_dict = {}
models = ['expansion_first_256_pcs','alexnet_conv5']
for model in models:
    data_dict[model] = load_model_dict(model)
    
name_dict = {'expansion_model':'Expansion Model PCs','alexnet_conv5':'Alexnet'}
palette = {'Expansion Model PCs':'mediumseagreen','Alexnet':'steelblue'}

# %%
plot_results(data_dict = data_dict, plot_type = 'compare_models', 
                 dataset = dataset, regions = regions,
                 palette=palette,
                 ylim = (0,0.37), 
                 width = 0.5, 
                 show_legend= True, 
                 params = (5.5,10), 
                 name_dict= name_dict, 
                 file_name=f'expansion_pcs_vs_alexnet')

# %% [markdown]
# # additional analysis

# %%
from model_evaluation.results.predicting_brain_data.tools import make_pandas_df
from model_evaluation.utils import get_activations_iden
import xarray as xr
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def get_scores_iden(iden, dataset, region, best_layer=False):
    
    models = []
    scores_path = os.path.join(CACHE,'encoding_scores')
    keywords =  [iden, region, dataset]
    
    if best_layer:
         keywords.append('best_layer')
    
    for iden in os.listdir(scores_path):
        if all(sub in iden for sub in keywords):
            models.append(iden)
    
    return sorted(models)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns



scores_df = pd.DataFrame({'name':[],'scores':[]})
dataset = 'naturalscenes'
#regions = ['general']
regions = ['V1','V2','V3','V4']
model_families = ['alexnet_conv','alexnet_untrained','expansion_model_3_layers_10000_features']


for model in model_families:
    
    scores_iden = []
    for region in regions:
        best_layer = True
        if 'expansion' in model:
            best_layer = False
        scores_iden.append(get_scores_iden(model, dataset, region, best_layer=best_layer)[0])
    
    all_voxels_scores = []
    model_names = []
    print(scores_iden)
    for iden in scores_iden:
        data = xr.open_dataset(os.path.join(CACHE,'encoding_scores',iden), engine='h5netcdf')

        r_values = list(data.r_value.values)
        name = [model for score in r_values]

        all_voxels_scores.extend(r_values)
        model_names.extend(name)
        
    scores_df = pd.concat([scores_df,pd.DataFrame({'name':model_names,'scores':all_voxels_scores})])
    
    
    
    
    

scores_df['name'] = scores_df['name'].map({'alexnet_conv':'AlexNet',
                           'alexnet_untrained':'AlexNet Untrained',
                           'expansion_model_3_layers_10000_features':'Expansion Model'})




palette = {'AlexNet':'steelblue', 
           'AlexNet Untrained':'darkgray',
           'Expansion Model':'mediumseagreen'}

rcParams['figure.figsize'] = (6,4) 
        
plt.rc('xtick', labelsize=12) 
plt.rc('ytick', labelsize=12) 
plt.ylabel('Density', fontsize=15)
plt.xlabel('Correlation (Pearson r)', fontsize=15)
plt.xticks(size=15)
plt.yticks(size=15)
sns.kdeplot(data = scores_df, x='scores',hue='name', fill=True, alpha=.2, linewidth=2,label=iden, palette=palette, bw=0.2)
#plt.legend(fontsize=30,loc='upper left')   
plt.savefig(f'kde_region={regions}.png', bbox_inches='tight', dpi=300, transparent=True)
# Out:
# ['alexnet_conv3_3_layers_384_features_naturalscenes_V1_best_layer', 'alexnet_conv3_3_layers_384_features_naturalscenes_V2_best_layer', 'alexnet_conv3_3_layers_384_features_naturalscenes_V3_best_layer', 'alexnet_conv3_3_layers_384_features_naturalscenes_V4_best_layer']
# ['alexnet_untrained_conv5_5_layers_256_features_naturalscenes_V1_best_layer', 'alexnet_untrained_conv5_5_layers_256_features_naturalscenes_V2_best_layer', 'alexnet_untrained_conv5_5_layers_256_features_naturalscenes_V3_best_layer', 'alexnet_untrained_conv3_3_layers_384_features_naturalscenes_V4_best_layer']
# ['expansion_model_3_layers_10000_features_naturalscenes_V1', 'expansion_model_3_layers_10000_features_naturalscenes_V2', 'expansion_model_3_layers_10000_features_naturalscenes_V3', 'expansion_model_3_layers_10000_features_naturalscenes_V4']

# %%
scores_df.groupby('name').mean()
# Out:
#                      scores
# name
# AlexNet            0.226006
# AlexNet Untrained  0.146359
# Expansion Model    0.234292

# %%
# import matplotlib.pyplot as plt
# from matplotlib import rcParams
# import seaborn as sns



# scores_df = pd.DataFrame({'name':[],'scores':[]})
# dataset = 'naturalscenes'
# regions = ['general']
# #regions = ['V1','V2','V3','V4']
# model_families = ['alexnet_conv','alexnet_untrained','expansion_model_3_layers_10000_features']


# for model in model_families:
    
#     scores_iden = []
#     for region in regions:
#         best_layer = True
#         if 'expansion' in model:
#             best_layer = False
#         iden = get_scores_iden(model, dataset, region, best_layer=best_layer)[0]
#         scores_iden.append(iden)
    

#     for iden in scores_iden:
#         data = xr.open_dataset(os.path.join(CACHE,'encoding_scores',iden), engine='h5netcdf')
        
#         all_voxels_scores = []
#         model_names = []
#         r_values = []
#         for subject in range(8):
#             s_data = data.where(data.subject==subject, drop=True)
#             r_values.append(s_data.r_value.values.mean())
        
#         name = [model for r_value in r_values]
#         all_voxels_scores.extend(r_values)
#         model_names.extend(name)
        
#         scores_df = pd.concat([scores_df,pd.DataFrame({'name':model_names,'scores':all_voxels_scores})])
    
    
    
    
    

# scores_df['name'] = scores_df['name'].map({'alexnet_conv':'AlexNet',
#                            'alexnet_untrained':'AlexNet Untrained',
#                            'expansion_model_3_layers_10000_features':'Expansion Model'})




# palette = {'AlexNet':'steelblue', 
#            'AlexNet Untrained':'darkgray',
#            'Expansion Model':'mediumseagreen'}

# rcParams['figure.figsize'] = (6,4) 
        
# plt.rc('xtick', labelsize=12) 
# plt.rc('ytick', labelsize=12) 
# plt.ylabel('Density', fontsize=15)
# plt.xlabel('Correlation (Pearson r)', fontsize=15)
# plt.xticks(size=15)
# plt.yticks(size=15)
# sns.kdeplot(data = scores_df, x='scores',hue='name', fill=True, alpha=.2, linewidth=2,label=iden, palette=palette)
# #plt.legend(fontsize=30,loc='upper left')   
# plt.savefig(f'kde_subject_means_region={regions}.png', bbox_inches='tight', dpi=300, transparent=True)
