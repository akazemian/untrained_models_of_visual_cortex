# %%
import os
import sys
ROOT = os.getenv('MB_ROOT_PATH')
sys.path.append(ROOT)

from plots.brain_map import *

# %%
import xarray as xr
import numpy as np
from scipy import stats

def process_data(data):

    data = data.drop_vars(["subject",'region','name']).to_array()
    data.x.values = data.x.values.astype(int)
    data.y.values = data.y.values.astype(int)
    data.z.values = data.z.values.astype(int)
    data = data.drop('variable').squeeze()
    
    return data

def process_subject(subject):
    expansion_mni = transform_volume_to_mni(
        data=reshape_dataarray_to_brain(
            data=process_data(expansion_scores_ds),
            subject=subject,
            resolution=resolution,
        ),
        subject=subject,
        source_space=f"func{resolution[:-2]}",
        interpolation_type=interpolation_type,
    )
    expansion_scores[:, subject] = expansion_mni.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors
# Define colors
colors = ['white', 'pink','palevioletred', 'black', 'mediumseagreen','palegreen', 'white']
#colors = ['lightgray','darkgray', 'black', 'mediumseagreen','palegreen']

# Create colormap
custom_cmap = LinearSegmentedColormap.from_list('CustomMap', colors)

# %%
# !pip install cmasher
import cmasher as cmr
custom_cmap = cmr.seaweed
# Out:
# Requirement already satisfied: cmasher in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (1.6.3)
# Requirement already satisfied: e13tools>=0.9.4 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from cmasher) (0.9.6)
# Requirement already satisfied: matplotlib>=2.2.4 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from cmasher) (3.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from cmasher) (1.20.3)
# Requirement already satisfied: colorspacious>=1.1.0 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from cmasher) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from matplotlib>=2.2.4->cmasher) (2.8.2)
# Requirement already satisfied: typing-extensions in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2.4->cmasher) (4.4.0)
# Requirement already satisfied: six>=1.5 in /home/akazemi3/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.4->cmasher) (1.16.0)

# %% [markdown]
# # Plotting brain maps

# %%
# custom_cmap = 'cold_hot'

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_conv1_mp_1_layers_64_features_naturalscenes/alexnet_conv1_mp_1_layers_64_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_conv1',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:20:49.590 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:20:49.602 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:20:53.277 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:20:53.287 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:20:56.993 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:20:57.001 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:00.624 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:00.632 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:04.197 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:04.206 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:07.838 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:07.849 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:11.601 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:11.609 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:15.219 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:15.227 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:19.690 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:19.700 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:23.466 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:23.476 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:27.093 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:27.102 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:30.756 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:30.764 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:34.440 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:34.448 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:38.103 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:38.113 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:41.774 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:41.782 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:45.388 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:21:45.396 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_u_conv1_mp_1_layers_64_features_naturalscenes/alexnet_u_conv1_mp_1_layers_64_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_u_conv1',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:25:33.237 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:33.245 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:36.952 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:36.961 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:40.940 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:40.950 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:44.662 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:44.671 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:48.162 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:48.170 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:51.893 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:51.903 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:55.521 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:55.528 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:59.144 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:25:59.152 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:02.844 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:02.851 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:06.442 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:06.450 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:09.992 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:10.000 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:13.675 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:13.684 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:17.168 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:17.176 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:20.773 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:20.783 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:24.385 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:24.393 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:27.897 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:26:27.904 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_conv2_mp_2_layers_192_features_naturalscenes/alexnet_conv2_mp_2_layers_192_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_conv2',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:30:21.775 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:21.783 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:25.196 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:25.204 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:28.600 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:28.609 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:32.066 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:32.075 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:35.471 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:35.479 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:38.935 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:38.945 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:42.425 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:42.433 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:45.875 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:45.883 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:49.414 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:49.422 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:52.955 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:52.964 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:56.385 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:56.394 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:59.852 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:30:59.861 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:03.275 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:03.283 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:06.756 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:06.766 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:10.247 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:10.254 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:13.691 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:31:13.699 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_u_conv2_mp_2_layers_192_features_naturalscenes/alexnet_u_conv2_mp_2_layers_192_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_u_conv2',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:35:03.616 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:03.625 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:07.097 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:07.105 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:10.477 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:10.486 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:13.857 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:13.866 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:17.219 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:17.227 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:20.648 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:20.658 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:24.065 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:24.073 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:27.434 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:27.441 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:30.937 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:30.945 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:34.435 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:34.444 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:37.825 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:37.834 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:41.257 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:41.266 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:44.611 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:44.620 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:48.073 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:48.084 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:51.699 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:51.710 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:55.116 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:35:55.123 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_conv3_mp_3_layers_384_features_naturalscenes/alexnet_conv3_mp_3_layers_384_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_conv3',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:39:45.133 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:45.141 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:48.576 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:48.585 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:51.952 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:51.961 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:55.328 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:55.337 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:58.682 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:39:58.691 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:02.176 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:02.186 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:05.579 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:05.587 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:08.946 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:08.954 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:12.416 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:12.423 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:15.858 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:15.867 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:19.232 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:19.241 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:22.709 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:22.719 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:26.076 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:26.084 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:29.492 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:29.502 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:32.897 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:32.905 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:36.265 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:40:36.272 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_u_conv3_mp_3_layers_384_features_naturalscenes/alexnet_u_conv3_mp_3_layers_384_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_u_conv3',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:44:25.021 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:25.029 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:28.443 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:28.451 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:31.775 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:31.783 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:35.149 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:35.158 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:38.489 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:38.497 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:41.876 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:41.886 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:45.282 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:45.290 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:48.643 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:48.650 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:52.086 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:52.094 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:55.503 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:55.511 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:58.838 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:44:58.846 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:02.218 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:02.227 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:05.544 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:05.553 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:08.952 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:08.962 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:12.380 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:12.387 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:15.741 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:45:15.749 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_conv4_mp_4_layers_256_features_naturalscenes/alexnet_conv4_mp_4_layers_256_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_conv4',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:49:05.658 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:05.666 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:09.023 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:09.031 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:12.312 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:12.321 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:15.636 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:15.645 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:18.971 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:18.979 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:22.313 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:22.324 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:25.664 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:25.671 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:28.974 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:28.982 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:32.320 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:32.328 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:35.743 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:35.752 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:39.018 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:39.027 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:42.337 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:42.346 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:45.648 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:45.656 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:48.983 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:48.993 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:52.352 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:52.360 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:55.697 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:49:55.705 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_u_conv4_mp_4_layers_256_features_naturalscenes/alexnet_u_conv4_mp_4_layers_256_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_u_conv4',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:53:46.304 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:46.312 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:49.685 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:49.693 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:52.968 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:52.977 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:56.299 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:56.308 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:59.582 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:53:59.591 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:02.949 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:02.959 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:06.314 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:06.322 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:09.630 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:09.638 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:12.999 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:13.007 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:16.410 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:16.418 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:19.694 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:19.703 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:23.021 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:23.030 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:26.299 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:26.307 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:29.648 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:29.658 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:33.008 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:33.016 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:36.334 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:54:36.342 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_conv5_mp_5_layers_256_features_naturalscenes/alexnet_conv5_mp_5_layers_256_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_conv5',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 11:58:26.039 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:26.047 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:29.444 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:29.453 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:32.742 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:32.751 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:36.209 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:36.218 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:39.581 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:39.590 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:43.289 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:43.304 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:47.130 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:47.139 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:51.041 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:51.048 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:54.444 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:54.452 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:57.857 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:58:57.865 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:01.176 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:01.185 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:04.571 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:04.580 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:07.983 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:07.991 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:11.352 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:11.362 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:14.741 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:14.749 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:18.086 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 11:59:18.094 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %%
scores_path = '/data/atlas/model_scores_final/expansion_model_mp_3_layers_10000_features_naturalscenes/expansion_model_mp_3_layers_10000_features_naturalscenes_general_ridgecv'
scores_path_2 = '/data/atlas/model_scores_final/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes_general_ridgecv'


subject = None

plot_brain_map(data= None,
               subject= subject, 
               cond = 'difference_of_means',
               scores_path = scores_path,
               scores_path_2 = scores_path_2,
               name=f'diff_alexnet_u_conv5',
              vmax = 0.3,
              cmap = custom_cmap)
# Out:
# 2023-07-11 12:03:10.277 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:10.285 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:13.669 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:13.678 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:16.980 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:16.988 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:20.337 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:20.346 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:23.625 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:23.633 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:26.969 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:26.980 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:30.330 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:30.338 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:33.657 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:33.665 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:36.981 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:36.989 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:40.370 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj02/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:40.379 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj02/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:43.654 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj03/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:43.663 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj03/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:46.985 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj04/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:46.994 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj04/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:50.275 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj05/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:50.284 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj05/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:53.646 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj06/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:53.656 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj06/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:57.016 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj07/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:03:57.024 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj07/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:04:00.331 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj08/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-11 12:04:00.339 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj08/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %% [markdown]
# # Getting subset of voxels for brainmap

# %%
def string_add(a, b, c):
    
    return a + b + c
    
    
def get_xyz(ds):
    
    ds = ds.assign_coords(x=ds['x'].astype(int).astype(str))
    ds = ds.assign_coords(y=ds['y'].astype(int).astype(str))
    ds = ds.assign_coords(z=ds['z'].astype(int).astype(str))
    
    return ds.assign_coords(xyz=xr.apply_ufunc(string_add, ds['x'], ds['y'], ds['z'], vectorize=True))

import xarray as xr
import numpy as np
from scipy import stats


expansion_scores = xr.open_dataset('/data/atlas/model_scores_final/expansion_model_rgb_test_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_test_mp_3_layers_10000_features_naturalscenes_general_test_ridge(alpha=1000)')
alexnet_scores = xr.open_dataset('/data/atlas/model_scores_final/alexnet_mp_5_layers_256_features_naturalscenes/alexnet_mp_5_layers_256_features_naturalscenes_general_test_ridge(alpha=100000)')

    

def get_subset(expansion_scores,alexnet_scores,regions,subject, diff=False):

        expansion_subject_scores = expansion_scores.where((expansion_scores.subject == subject),drop=True)
        alexnet_subject_scores = alexnet_scores.where((alexnet_scores.subject == subject),drop=True)

        coords_list = []
        
        for region in regions:

            path = f'/data/rgautha1/cache/bonner-caching/neural-dimensionality/data/dataset=allen2021.natural_scenes/resolution=1pt8mm.preprocessing=fithrf_GLMdenoise_RR/roi={region}/preprocessed/z_score=session.average_across_reps=True/subject={subject}.nc'
            region_coords = xr.open_dataset(path)
            var_name = f'allen2021.natural_scenes.preprocessing=fithrf_GLMdenoise_RR.roi={region}.z_score=session.average_across_reps=True.subject={subject}'
            region_coords = region_coords.rename({var_name:'vals'})
            coords_list.append(region_coords)        
        
        all_region_coords = xr.concat(coords_list, dim='neuroid')
        
        
        all_region_coords = get_xyz(all_region_coords)
        expansion_subject_scores = get_xyz(expansion_subject_scores)
        alexnet_subject_scores = get_xyz(alexnet_subject_scores)
        
        
        if not diff:
            expansion_subject_scores = expansion_subject_scores.where(
                expansion_subject_scores.neuroid.xyz.isin([all_region_coords.xyz]),drop=True)
            
            alexnet_subject_scores = alexnet_subject_scores.where(
                alexnet_subject_scores.neuroid.xyz.isin([all_region_coords.xyz]),drop=True)
            
        else:
            
            expansion_subject_scores = expansion_subject_scores.where(~
                expansion_subject_scores.neuroid.xyz.isin([all_region_coords.xyz]),drop=True)

            alexnet_subject_scores = alexnet_subject_scores.where(~
                alexnet_subject_scores.neuroid.xyz.isin([all_region_coords.xyz]),drop=True)
            
        return expansion_subject_scores, alexnet_subject_scores

# %% [markdown]
# # Statistical analysis

# %%
expansion_scores_ds = xr.open_dataset('/data/atlas/model_scores_final/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes_general_ridgecv')
expansion_scores = np.zeros((mni_shape,8))

alexnet_scores_ds = xr.open_dataset('/data/atlas/model_scores_final/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes_general_ridgecv')
alexnet_scores = np.zeros((mni_shape,8))


for subject in range(8):      
        

    expansion_mni = transform_volume_to_mni(
        data=reshape_dataarray_to_brain(
            data=process_subject(expansion_scores_ds),
            subject=subject,
            resolution=resolution,
        ),
        subject=subject,
        source_space=f"func{resolution[:-2]}",
        interpolation_type=interpolation_type,
    )
    expansion_scores[:,subject] = expansion_mni.flatten()
    
    
    alexnet_mni = transform_volume_to_mni(
        data=reshape_dataarray_to_brain(
            data=process_subject(alexnet_scores_ds),
            subject=subject,
            resolution=resolution,
        ),
        subject=subject,
        source_space=f"func{resolution[:-2]}",
        interpolation_type=interpolation_type,
    )
    alexnet_scores[:,subject] = alexnet_mni.flatten()
# Out:
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/data/atlas/model_scores_final/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes_general_ridgecv',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                    Traceback (most recent call last)
# <ipython-input-21-6caedf35e614> in <module>
# ----> 1 expansion_scores_ds = xr.open_dataset('/data/atlas/model_scores_final/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes_general_ridgecv')
#       2 expansion_scores = np.zeros((mni_shape,8))
#       3
#       4 alexnet_scores_ds = xr.open_dataset('/data/atlas/model_scores_final/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes_general_ridgecv')
#       5 alexnet_scores = np.zeros((mni_shape,8))
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     552
#     553         opener = _get_backend_cls(engine)
# --> 554         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     555
#     556     with close_on_error(store):
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     376             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     377         )
# --> 378         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     379
#     380     def _acquire(self, needs_lock=True):
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     324         self._group = group
#     325         self._mode = mode
# --> 326         self.format = self.ds.data_model
#     327         self._filename = self.ds.filepath()
#     328         self.is_remote = is_remote_uri(self._filename)
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     385     @property
#     386     def ds(self):
# --> 387         return self._acquire()
#     388
#     389     def open_store_variable(self, name, var):
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     379
#     380     def _acquire(self, needs_lock=True):
# --> 381         with self._manager.acquire_context(needs_lock) as root:
#     382             ds = _nc4_require_group(root, self._group, self._mode)
#     383         return ds
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/.conda/envs/bonner-lab-atlas/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/data/atlas/model_scores_final/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_mp_3_layers_10000_features_naturalscenes_general_ridgecv'

# %%
# import multiprocessing as mp

# expansion_scores_ds = xr.open_dataset('/data/atlas/model_scores_final/expansion_model_rgb_test_mp_3_layers_10000_features_naturalscenes/expansion_model_rgb_test_mp_3_layers_10000_features_naturalscenes_general_test_ridge(alpha=1000)')

# manager = mp.Manager()
# expansion_scores = manager.Array('d', mni_shape * 8)  # Shared array for expansion_scores

# pool = mp.Pool(processes=8)
# pool.map(process_subject, range(8))
# pool.close()
# pool.join()

# expansion_scores = np.frombuffer(expansion_scores.get_obj(), dtype=np.float64).reshape(mni_shape, 8)

# %%
def filter_zero_rows(arr1, arr2):
    # Get a boolean mask indicating rows where all column values are zero in both arrays
    mask = np.all(arr1 == 0, axis=1) & np.all(arr2 == 0, axis=1)
    
    # Filter the arrays based on the mask
    filtered_arr1 = arr1[~mask]
    filtered_arr2 = arr2[~mask]
    
    return filtered_arr1, filtered_arr2


# Perform paired t-test
t_statistic, p_value = stats.ttest_rel(expansion_scores, alexnet_scores, axis=1)

th = 0.001
sig_voxels = np.where(p_value <= th)[0]
all_voxels = np.where(~np.isnan(p_value))[0]
print(f'percentage of voxels with p-value < {th}:',round(len(sig_voxels)/len(all_voxels),2))
# Out:
# percentage of voxels with p-value < 0.001: 0.03

# %%
def set_values_to_zero(arr, th=0.001):
    arr[arr > th] = 0
    return arr

# Set values smaller than 0.001 to zero
masked_p_values = set_values_to_zero(p_value)
masked_p_values_brain = np.nan_to_num(masked_p_values.reshape((182, 218, 182)))

volume = convert_ndarray_to_nifti1image(masked_p_values_brain)

fig, _ = nilearn.plotting.plot_img_on_surf(
    volume,
    views=["lateral", "medial", "ventral"],
    hemispheres=["left", "right"],
    colorbar=True,
    inflate=True,
    surf_mesh='fsaverage',
    threshold=np.finfo(np.float32).resolution,
    symmetric_cbarbool='auto',
)
fig.savefig('significant_p_values',dpi=300)

# %% [markdown]
# # Plotting Brain for Visualization

# %%
resolution = '1pt8mm'      
interpolation_type = 'nearest'
subject = 0
colors = ['White','slategray']
custom_cmap = LinearSegmentedColormap.from_list('CustomMap', colors)

# %% [markdown]
# ### V1-V4

# %%
regions = ['V1','V2','V3','V4']

scores_list = []
for region in regions:
    data = xr.open_dataset(f'/data/atlas/model_scores_final/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes_{region}_ridgecv')
    data = data.where(data.subject == subject,drop=True)
    scores_list.append(data)
scores = xr.concat(scores_list, dim='neuroid')



alexnet_mni = transform_volume_to_mni(
    data=reshape_dataarray_to_brain(
        data=process_data(scores),
        subject=subject,
        resolution=resolution,
    ),
    subject=subject,
    source_space=f"func{resolution[:-2]}",
    interpolation_type=interpolation_type,
)




brain_region = np.where(alexnet_mni > 0, 1,0)
volume = convert_ndarray_to_nifti1image(brain_region)

fig, _ = nilearn.plotting.plot_img_on_surf(
    volume,
    views=["lateral", "medial", "ventral"],
    hemispheres=["left", "right"],
    colorbar=True,
    inflate=True,
    surf_mesh='fsaverage',
    threshold=np.finfo(np.float32).resolution,
    symmetric_cbarbool='auto',
    cmap = custom_cmap, 
    vmax = 1
)
fig.savefig(f'just_brain_{regions}',dpi=300)
# Out:
# 2023-07-13 14:31:49.477 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-13 14:31:49.485 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset

# %% [markdown]
# ### general

# %%
regions = ['general']



scores_list = []
for region in regions:
    data = xr.open_dataset(f'/data/atlas/model_scores_final/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes/alexnet_u_conv5_mp_5_layers_256_features_naturalscenes_{region}_ridgecv')
    data = data.where(data.subject == subject,drop=True)
    scores_list.append(data)
scores = xr.concat(scores_list, dim='neuroid')




alexnet_mni = transform_volume_to_mni(
    data=reshape_dataarray_to_brain(
        data=process_data(scores),
        subject=subject,
        resolution=resolution,
    ),
    subject=subject,
    source_space=f"func{resolution[:-2]}",
    interpolation_type=interpolation_type,
)





brain_region = np.where(alexnet_mni > 0, 1,0)
volume = convert_ndarray_to_nifti1image(brain_region)

fig, _ = nilearn.plotting.plot_img_on_surf(
    volume,
    views=["lateral", "medial", "ventral"],
    hemispheres=["left", "right"],
    colorbar=True,
    inflate=True,
    surf_mesh='fsaverage',
    threshold=np.finfo(np.float32).resolution,
    symmetric_cbarbool='auto',
    cmap = custom_cmap, 
    vmax = 1
)
fig.savefig(f'just_brain_{regions}',dpi=300)
# Out:
# 2023-07-13 14:39:26.231 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz instead of downloading nsddata/ppdata/subj01/func1pt8mm/brainmask.nii.gz from S3 bucket natural-scenes-dataset
# 2023-07-13 14:39:26.239 | DEBUG    | plots.brain_map:download_from_s3:117 - Using previously downloaded file at /data/atlas/brain_map/allen2021.natural_scenes/nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz instead of downloading nsddata/ppdata/subj01/transforms/func1pt8-to-MNI.nii.gz from S3 bucket natural-scenes-dataset
